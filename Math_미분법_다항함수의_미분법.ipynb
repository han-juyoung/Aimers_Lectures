# %% [markdown]
# <a href="https://colab.research.google.com/github/han-juyoung/Aimers_Lectures/blob/main/Math_%EB%AF%B8%EB%B6%84%EB%B2%95_%EB%8B%A4%ED%95%AD%ED%95%A8%EC%88%98%EC%9D%98_%EB%AF%B8%EB%B6%84%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from elice_utils import EliceUtils
import numpy as np

elice_utils = EliceUtils()

def main():
    x = 5
    print(derivative(x))


def derivative(x):
    '''
    먼저 다항함수 $x^2+1$을 선언하세요.그리고 선언한 다항함수의 미분 함수를 정의하고, 이것에  x를 넣은 값을 출력하세요.
    '''
    p = np.poly1d([1,0,1])
    print(p)

    q = p.deriv()
    print(q)

    return q(x)


if __name__ == "__main__":
    main()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
