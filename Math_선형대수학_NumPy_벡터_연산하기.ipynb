# %% [markdown]
# <a href="https://colab.research.google.com/github/han-juyoung/Aimers_Lectures/blob/main/Math_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98%ED%95%99_NumPy_%EB%B2%A1%ED%84%B0_%EC%97%B0%EC%82%B0%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from elice_utils import EliceUtils
import numpy as np

elice_utils = EliceUtils()

def main():
    data = [1,2,3]

    print(calculate_norm(data))
    print(unit_vector(data))


def calculate_norm(data):
    '''
    지시사항1: 함수 안에 주어진 데이터 data의 크기(scale) 값을 출력하는 함수를 채우시오.
    '''

    return np.linalg.norm(data)

def unit_vector(data):
    '''
    지시사항2: 함수 입력으로 주어진 data 벡터를 단위 벡터(unit vector)로 바꾸어 출력하세요.
    '''

    return np.array(data) / np.linalg.norm(data)

if __name__ == "__main__":
    main()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
