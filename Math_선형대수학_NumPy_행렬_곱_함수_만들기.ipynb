# %% [markdown]
# <a href="https://colab.research.google.com/github/han-juyoung/Aimers_Lectures/blob/main/Math_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98%ED%95%99_NumPy_%ED%96%89%EB%A0%AC_%EA%B3%B1_%ED%95%A8%EC%88%98_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from elice_utils import EliceUtils
import numpy as np

elice_utils = EliceUtils()


def main():

    print(multiply())

def multiply():
    '''
    함수 안에 먼저 1으로 채워진 행렬 2개를 선언합니다. 하나는 (5,3)의 크기, 다른 하나는 (3,2)로 합니다. 그리고 앞서 선언한 두 행렬의 곱을 합니다.
    '''
    # A = np.ones((5, 3))
    # B = np.ones((3, 2))
    # Z = np.dot(A, B)
    Z = np.dot(np.ones((5, 3)), np.ones((3, 2)))

    return Z



if __name__ == "__main__":
    main()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
