# %% [markdown]
# <a href="https://colab.research.google.com/github/han-juyoung/Aimers_Lectures/blob/main/Math_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98%ED%95%99_NumPy_%ED%96%89%EB%A0%AC_%EC%97%B0%EC%82%B0%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from elice_utils import EliceUtils
import numpy as np

elice_utils = EliceUtils()

def main():

    Z = normalize()
    print(Z.max() - Z.min()) # 1 - 0 = 1

def normalize():
    '''
    지시사항: 함수 안에서 먼저 (5,5)의 랜덤 행렬을 선언하세요.그리고 선언한 행렬의 최대값과 최소값을 기억하고, 이것을 통해 선언했던 랜덤 행렬을 normalize하세요.
    '''

    Z = np.random.random((5,5))
    Zmax, Zmin = Z.max(), Z.min()
    Z = (Z-Zmin) / (Zmax-Zmin)

    return Z

if __name__ == "__main__":
    main()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
